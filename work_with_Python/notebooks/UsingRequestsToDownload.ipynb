# %% [markdown]
# While urllib is a good built-in option, there may be scenarios where you need to use third-party libraries to make more advanced HTTP requests, such as those requiring some form of authentication.
# The requests library is a popular, user-friendly, and Pythonic API for making HTTP requests in Python.
# It can handle the complexities of low-level network communication behind the curtain.
# The requests library is also known for its flexibility and offers tighter control over the download process, allowing you to customize it according to your project requirements.
# Some examples include the ability to specify request headers, handle cookies, access data behind login-gated web pages, stream data in chunks, and more.
# In addition, the library is designed to be efficient and performant by supporting various features that enhance the overall download performance.
# Its ability to automatically handle connection pooling and reuse optimizes network utilization and reduces overhead.
#
# Important Moments:
# 1. Always use `raise_for_status()` to catch HTTP errors
# 2. Stream large files using `stream=True` and `iter_content()`
# 3. Add proper error handling for network issues
# 4. Use progress bars for better user experience
# 5. Validate downloaded files when content integrity is important
# 6. Consider rate limiting when downloading multiple files
# 7. Handle timeouts for slow connections

# %%
import requests

url = "https://api.worldbank.org/v2/en/indicator/NY.GDP.MKTP.CD"

query_parameters = {"downloadformat": "csv"}

# %% [markdown]
# In the example above, you define the same URL as before but specify the downloadformat=csv parameter separately using a Python dictionary.
# The library will append those parameters to the URL after you pass them to requests.get() using an optional params argument.
# The response object provides several other convenient attributes that you can check out.
# For example, these two will let you determine if the request was successful and what HTTP status code the server returned:

# %%
response = requests.get(url, params=query_parameters)

print(f"url: {response.url}")

# a status code of 200 indicates that your request has been completed successfully 
if response.ok:
    print(f"response is ok: {response.ok}")
    
print(f"response status is {response.status_code}")
# Out:
# url: https://api.worldbank.org/v2/en/indicator/NY.GDP.MKTP.CD?downloadformat=csv
# response is ok: True
# response status is 200

# %% [markdown]
# There are a few ways in which you can access data retrieved with the requests library, depending on content type.
# In particular, when you want to save the original data to a local file, then you’ll use the .content attribute of the returned response object.
# Because this attribute holds raw bytes, you’ll open a new file in binary mode for writing ('wb') and then write the downloaded content to the file

# %%
result_file_name = "gdp_by_country.zip"

with open(result_file_name, mode="wb") as file:
    file.write(response.content)

print(f"the file {result_file_name} is downloaded")
# Out:
# the file gdp_by_country.zip is downloaded

# %% [markdown]
# ** Big files download options

# %%
url = "https://databank.worldbank.org/data/download/WDI_CSV.zip"
response = requests.get(url, stream=True)

response.headers
# Out:
# {'Date': 'Mon, 03 Mar 2025 16:57:00 GMT', 'Content-Type': 'application/octet-stream', 'Content-Length': '271822139', 'Connection': 'keep-alive', 'Last-Modified': 'Tue, 28 Jan 2025 19:30:22 GMT', 'ETag': '0x8DD3FD234F14A8D', 'x-ms-request-id': 'ad6ba1b6-201e-0007-54b8-87470c000000', 'x-ms-version': '2009-09-19', 'x-ms-lease-status': 'unlocked', 'x-ms-blob-type': 'BlockBlob', 'x-azure-ref': '20250303T165700Z-er19df8ddfbdsqlzhC1EWRkbgg00000006cg0000000066c7', 'Cache-Control': 'public, max-age=3600', 'x-fd-int-roxy-purgeid': '83708083', 'X-Cache-Info': 'L2_T2', 'X-Cache': 'TCP_REMOTE_HIT', 'Accept-Ranges': 'bytes'}

# %%
if response.ok:
    cnt = 0
    chunk_size = 100000
    with open("WDI_CSV.zip", mode="wb") as file:
        for chunk in response.iter_content(chunk_size=chunk_size):
            file.write(chunk)
            cnt += 1
            print(f"downloaded chank {cnt}")

    print(f"the whole file is downloaded")
else:
    print(f"request failed, status: {response.status}")
# Out:
# downloaded chank 1
# downloaded chank 2
# downloaded chank 3
# downloaded chank 4
# downloaded chank 5
# downloaded chank 6
# downloaded chank 7
# downloaded chank 8
# downloaded chank 9
# downloaded chank 10
# downloaded chank 11
# downloaded chank 12
# downloaded chank 13
# downloaded chank 14
# downloaded chank 15
# downloaded chank 16
# downloaded chank 17
# downloaded chank 18
# downloaded chank 19
# downloaded chank 20
# downloaded chank 21
# downloaded chank 22
# downloaded chank 23
# downloaded chank 24
# downloaded chank 25
# downloaded chank 26
# downloaded chank 27
# downloaded chank 28
# downloaded chank 29
# downloaded chank 30
# downloaded chank 31
# downloaded chank 32
# downloaded chank 33
# downloaded chank 34
# downloaded chank 35
# downloaded chank 36
# downloaded chank 37
# downloaded chank 38
# downloaded chank 39
# downloaded chank 40
# downloaded chank 41
# downloaded chank 42
# downloaded chank 43
# downloaded chank 44
# downloaded chank 45
# downloaded chank 46
# downloaded chank 47
# downloaded chank 48
# downloaded chank 49
# downloaded chank 50
# downloaded chank 51
# downloaded chank 52
# downloaded chank 53
# downloaded chank 54
# downloaded chank 55
# downloaded chank 56
# downloaded chank 57
# downloaded chank 58
# downloaded chank 59
# downloaded chank 60
# downloaded chank 61
# downloaded chank 62
# downloaded chank 63
# downloaded chank 64
# downloaded chank 65
# downloaded chank 66
# downloaded chank 67
# downloaded chank 68
# downloaded chank 69
# downloaded chank 70
# downloaded chank 71
# downloaded chank 72
# downloaded chank 73
# downloaded chank 74
# downloaded chank 75
# downloaded chank 76
# downloaded chank 77
# downloaded chank 78
# downloaded chank 79
# downloaded chank 80
# downloaded chank 81
# downloaded chank 82
# downloaded chank 83
# downloaded chank 84
# downloaded chank 85
# downloaded chank 86
# downloaded chank 87
# downloaded chank 88
# downloaded chank 89
# downloaded chank 90
# downloaded chank 91
# downloaded chank 92
# downloaded chank 93
# downloaded chank 94
# downloaded chank 95
# downloaded chank 96
# downloaded chank 97
# downloaded chank 98
# downloaded chank 99
# downloaded chank 100
# downloaded chank 101
# downloaded chank 102
# downloaded chank 103
# downloaded chank 104
# downloaded chank 105
# downloaded chank 106
# downloaded chank 107
# downloaded chank 108
# downloaded chank 109
# downloaded chank 110
# downloaded chank 111
# downloaded chank 112
# downloaded chank 113
# downloaded chank 114
# downloaded chank 115
# downloaded chank 116
# downloaded chank 117
# downloaded chank 118
# downloaded chank 119
# downloaded chank 120
# downloaded chank 121
# downloaded chank 122
# downloaded chank 123
# downloaded chank 124
# downloaded chank 125
# downloaded chank 126
# downloaded chank 127
# downloaded chank 128
# downloaded chank 129
# downloaded chank 130
# downloaded chank 131
# downloaded chank 132
# downloaded chank 133
# downloaded chank 134
# downloaded chank 135
# downloaded chank 136
# downloaded chank 137
# downloaded chank 138
# downloaded chank 139
# downloaded chank 140
# downloaded chank 141
# downloaded chank 142
# downloaded chank 143
# downloaded chank 144
# downloaded chank 145
# downloaded chank 146
# downloaded chank 147
# downloaded chank 148
# downloaded chank 149
# downloaded chank 150
# downloaded chank 151
# downloaded chank 152
# downloaded chank 153
# downloaded chank 154
# downloaded chank 155
# downloaded chank 156
# downloaded chank 157
# downloaded chank 158
# downloaded chank 159
# downloaded chank 160
# downloaded chank 161
# downloaded chank 162
# downloaded chank 163
# downloaded chank 164
# downloaded chank 165
# downloaded chank 166
# downloaded chank 167
# downloaded chank 168
# downloaded chank 169
# downloaded chank 170
# downloaded chank 171
# downloaded chank 172
# downloaded chank 173
# downloaded chank 174
# downloaded chank 175
# downloaded chank 176
# downloaded chank 177
# downloaded chank 178
# downloaded chank 179
# downloaded chank 180
# downloaded chank 181
# downloaded chank 182
# downloaded chank 183
# downloaded chank 184
# downloaded chank 185
# downloaded chank 186
# downloaded chank 187
# downloaded chank 188
# downloaded chank 189
# downloaded chank 190
# downloaded chank 191
# downloaded chank 192
# downloaded chank 193
# downloaded chank 194
# downloaded chank 195
# downloaded chank 196
# downloaded chank 197
# downloaded chank 198
# downloaded chank 199
# downloaded chank 200
# downloaded chank 201
# downloaded chank 202
# downloaded chank 203
# downloaded chank 204
# downloaded chank 205
# downloaded chank 206
# downloaded chank 207
# downloaded chank 208
# downloaded chank 209
# downloaded chank 210
# downloaded chank 211
# downloaded chank 212
# downloaded chank 213
# downloaded chank 214
# downloaded chank 215
# downloaded chank 216
# downloaded chank 217
# downloaded chank 218
# downloaded chank 219
# downloaded chank 220
# downloaded chank 221
# downloaded chank 222
# downloaded chank 223
# downloaded chank 224
# downloaded chank 225
# downloaded chank 226
# downloaded chank 227
# downloaded chank 228
# downloaded chank 229
# downloaded chank 230
# downloaded chank 231
# downloaded chank 232
# downloaded chank 233
# downloaded chank 234
# downloaded chank 235
# downloaded chank 236
# downloaded chank 237
# downloaded chank 238
# downloaded chank 239
# downloaded chank 240
# downloaded chank 241
# downloaded chank 242
# downloaded chank 243
# downloaded chank 244
# downloaded chank 245
# downloaded chank 246
# downloaded chank 247
# downloaded chank 248
# downloaded chank 249
# downloaded chank 250
# downloaded chank 251
# downloaded chank 252
# downloaded chank 253
# downloaded chank 254
# downloaded chank 255
# downloaded chank 256
# downloaded chank 257
# downloaded chank 258
# downloaded chank 259
# downloaded chank 260
# downloaded chank 261
# downloaded chank 262
# downloaded chank 263
# downloaded chank 264
# downloaded chank 265
# downloaded chank 266
# downloaded chank 267
# downloaded chank 268
# downloaded chank 269
# downloaded chank 270
# downloaded chank 271
# downloaded chank 272
# downloaded chank 273
# downloaded chank 274
# downloaded chank 275
# downloaded chank 276
# downloaded chank 277
# downloaded chank 278
# downloaded chank 279
# downloaded chank 280
# downloaded chank 281
# downloaded chank 282
# downloaded chank 283
# downloaded chank 284
# downloaded chank 285
# downloaded chank 286
# downloaded chank 287
# downloaded chank 288
# downloaded chank 289
# downloaded chank 290
# downloaded chank 291
# downloaded chank 292
# downloaded chank 293
# downloaded chank 294
# downloaded chank 295
# downloaded chank 296
# downloaded chank 297
# downloaded chank 298
# downloaded chank 299
# downloaded chank 300
# downloaded chank 301
# downloaded chank 302
# downloaded chank 303
# downloaded chank 304
# downloaded chank 305
# downloaded chank 306
# downloaded chank 307
# downloaded chank 308
# downloaded chank 309
# downloaded chank 310
# downloaded chank 311
# downloaded chank 312
# downloaded chank 313
# downloaded chank 314
# downloaded chank 315
# downloaded chank 316
# downloaded chank 317
# downloaded chank 318
# downloaded chank 319
# downloaded chank 320
# downloaded chank 321
# downloaded chank 322
# downloaded chank 323
# downloaded chank 324
# downloaded chank 325
# downloaded chank 326
# downloaded chank 327
# downloaded chank 328
# downloaded chank 329
# downloaded chank 330
# downloaded chank 331
# downloaded chank 332
# downloaded chank 333
# downloaded chank 334
# downloaded chank 335
# downloaded chank 336
# downloaded chank 337
# downloaded chank 338
# downloaded chank 339
# downloaded chank 340
# downloaded chank 341
# downloaded chank 342
# downloaded chank 343
# downloaded chank 344
# downloaded chank 345
# downloaded chank 346
# downloaded chank 347
# downloaded chank 348
# downloaded chank 349
# downloaded chank 350
# downloaded chank 351
# downloaded chank 352
# downloaded chank 353
# downloaded chank 354
# downloaded chank 355
# downloaded chank 356
# downloaded chank 357
# downloaded chank 358
# downloaded chank 359
# downloaded chank 360
# downloaded chank 361
# downloaded chank 362
# downloaded chank 363
# downloaded chank 364
# downloaded chank 365
# downloaded chank 366
# downloaded chank 367
# downloaded chank 368
# downloaded chank 369
# downloaded chank 370
# downloaded chank 371
# downloaded chank 372
# downloaded chank 373
# downloaded chank 374
# downloaded chank 375
# downloaded chank 376
# downloaded chank 377
# downloaded chank 378
# downloaded chank 379
# downloaded chank 380
# downloaded chank 381
# downloaded chank 382
# downloaded chank 383
# downloaded chank 384
# downloaded chank 385
# downloaded chank 386
# downloaded chank 387
# downloaded chank 388
# downloaded chank 389
# downloaded chank 390
# downloaded chank 391
# downloaded chank 392
# downloaded chank 393
# downloaded chank 394
# downloaded chank 395
# downloaded chank 396
# downloaded chank 397
# downloaded chank 398
# downloaded chank 399
# downloaded chank 400
# downloaded chank 401
# downloaded chank 402
# downloaded chank 403
# downloaded chank 404
# downloaded chank 405
# downloaded chank 406
# downloaded chank 407
# downloaded chank 408
# downloaded chank 409
# downloaded chank 410
# downloaded chank 411
# downloaded chank 412
# downloaded chank 413
# downloaded chank 414
# downloaded chank 415
# downloaded chank 416
# downloaded chank 417
# downloaded chank 418
# downloaded chank 419
# downloaded chank 420
# downloaded chank 421
# downloaded chank 422
# downloaded chank 423
# downloaded chank 424
# downloaded chank 425
# downloaded chank 426
# downloaded chank 427
# downloaded chank 428
# downloaded chank 429
# downloaded chank 430
# downloaded chank 431
# downloaded chank 432
# downloaded chank 433
# downloaded chank 434
# downloaded chank 435
# downloaded chank 436
# downloaded chank 437
# downloaded chank 438
# downloaded chank 439
# downloaded chank 440
# downloaded chank 441
# downloaded chank 442
# downloaded chank 443
# downloaded chank 444
# downloaded chank 445
# downloaded chank 446
# downloaded chank 447
# downloaded chank 448
# downloaded chank 449
# downloaded chank 450
# downloaded chank 451
# downloaded chank 452
# downloaded chank 453
# downloaded chank 454
# downloaded chank 455
# downloaded chank 456
# downloaded chank 457
# downloaded chank 458
# downloaded chank 459
# downloaded chank 460
# downloaded chank 461
# downloaded chank 462
# downloaded chank 463
# downloaded chank 464
# downloaded chank 465
# downloaded chank 466
# downloaded chank 467
# downloaded chank 468
# downloaded chank 469
# downloaded chank 470
# downloaded chank 471
# downloaded chank 472
# downloaded chank 473
# downloaded chank 474
# downloaded chank 475
# downloaded chank 476
# downloaded chank 477
# downloaded chank 478
# downloaded chank 479
# downloaded chank 480
# downloaded chank 481
# downloaded chank 482
# downloaded chank 483
# downloaded chank 484
# downloaded chank 485
# downloaded chank 486
# downloaded chank 487
# downloaded chank 488
# downloaded chank 489
# downloaded chank 490
# downloaded chank 491
# downloaded chank 492
# downloaded chank 493
# downloaded chank 494
# downloaded chank 495
# downloaded chank 496
# downloaded chank 497
# downloaded chank 498
# downloaded chank 499
# downloaded chank 500
# downloaded chank 501
# downloaded chank 502
# downloaded chank 503
# downloaded chank 504
# downloaded chank 505
# downloaded chank 506
# downloaded chank 507
# downloaded chank 508
# downloaded chank 509
# downloaded chank 510
# downloaded chank 511
# downloaded chank 512
# downloaded chank 513
# downloaded chank 514
# downloaded chank 515
# downloaded chank 516
# downloaded chank 517
# downloaded chank 518
# downloaded chank 519
# downloaded chank 520
# downloaded chank 521
# downloaded chank 522
# downloaded chank 523
# downloaded chank 524
# downloaded chank 525
# downloaded chank 526
# downloaded chank 527
# downloaded chank 528
# downloaded chank 529
# downloaded chank 530
# downloaded chank 531
# downloaded chank 532
# downloaded chank 533
# downloaded chank 534
# downloaded chank 535
# downloaded chank 536
# downloaded chank 537
# downloaded chank 538
# downloaded chank 539
# downloaded chank 540
# downloaded chank 541
# downloaded chank 542
# downloaded chank 543
# downloaded chank 544
# downloaded chank 545
# downloaded chank 546
# downloaded chank 547
# downloaded chank 548
# downloaded chank 549
# downloaded chank 550
# downloaded chank 551
# downloaded chank 552
# downloaded chank 553
# downloaded chank 554
# downloaded chank 555
# downloaded chank 556
# downloaded chank 557
# downloaded chank 558
# downloaded chank 559
# downloaded chank 560
# downloaded chank 561
# downloaded chank 562
# downloaded chank 563
# downloaded chank 564
# downloaded chank 565
# downloaded chank 566
# downloaded chank 567
# downloaded chank 568
# downloaded chank 569
# downloaded chank 570
# downloaded chank 571
# downloaded chank 572
# downloaded chank 573
# downloaded chank 574
# downloaded chank 575
# downloaded chank 576
# downloaded chank 577
# downloaded chank 578
# downloaded chank 579
# downloaded chank 580
# downloaded chank 581
# downloaded chank 582
# downloaded chank 583
# downloaded chank 584
# downloaded chank 585
# downloaded chank 586
# downloaded chank 587
# downloaded chank 588
# downloaded chank 589
# downloaded chank 590
# downloaded chank 591
# downloaded chank 592
# downloaded chank 593
# downloaded chank 594
# downloaded chank 595
# downloaded chank 596
# downloaded chank 597
# downloaded chank 598
# downloaded chank 599
# downloaded chank 600
# downloaded chank 601
# downloaded chank 602
# downloaded chank 603
# downloaded chank 604
# downloaded chank 605
# downloaded chank 606
# downloaded chank 607
# downloaded chank 608
# downloaded chank 609
# downloaded chank 610
# downloaded chank 611
# downloaded chank 612
# downloaded chank 613
# downloaded chank 614
# downloaded chank 615
# downloaded chank 616
# downloaded chank 617
# downloaded chank 618
# downloaded chank 619
# downloaded chank 620
# downloaded chank 621
# downloaded chank 622
# downloaded chank 623
# downloaded chank 624
# downloaded chank 625
# downloaded chank 626
# downloaded chank 627
# downloaded chank 628
# downloaded chank 629
# downloaded chank 630
# downloaded chank 631
# downloaded chank 632
# downloaded chank 633
# downloaded chank 634
# downloaded chank 635
# downloaded chank 636
# downloaded chank 637
# downloaded chank 638
# downloaded chank 639
# downloaded chank 640
# downloaded chank 641
# downloaded chank 642
# downloaded chank 643
# downloaded chank 644
# downloaded chank 645
# downloaded chank 646
# downloaded chank 647
# downloaded chank 648
# downloaded chank 649
# downloaded chank 650
# downloaded chank 651
# downloaded chank 652
# downloaded chank 653
# downloaded chank 654
# downloaded chank 655
# downloaded chank 656
# downloaded chank 657
# downloaded chank 658
# downloaded chank 659
# downloaded chank 660
# downloaded chank 661
# downloaded chank 662
# downloaded chank 663
# downloaded chank 664
# downloaded chank 665
# downloaded chank 666
# downloaded chank 667
# downloaded chank 668
# downloaded chank 669
# downloaded chank 670
# downloaded chank 671
# downloaded chank 672
# downloaded chank 673
# downloaded chank 674
# downloaded chank 675
# downloaded chank 676
# downloaded chank 677
# downloaded chank 678
# downloaded chank 679
# downloaded chank 680
# downloaded chank 681
# downloaded chank 682
# downloaded chank 683
# downloaded chank 684
# downloaded chank 685
# downloaded chank 686
# downloaded chank 687
# downloaded chank 688
# downloaded chank 689
# downloaded chank 690
# downloaded chank 691
# downloaded chank 692
# downloaded chank 693
# downloaded chank 694
# downloaded chank 695
# downloaded chank 696
# downloaded chank 697
# downloaded chank 698
# downloaded chank 699
# downloaded chank 700
# downloaded chank 701
# downloaded chank 702
# downloaded chank 703
# downloaded chank 704
# downloaded chank 705
# downloaded chank 706
# downloaded chank 707
# downloaded chank 708
# downloaded chank 709
# downloaded chank 710
# downloaded chank 711
# downloaded chank 712
# downloaded chank 713
# downloaded chank 714
# downloaded chank 715
# downloaded chank 716
# downloaded chank 717
# downloaded chank 718
# downloaded chank 719
# downloaded chank 720
# downloaded chank 721
# downloaded chank 722
# downloaded chank 723
# downloaded chank 724
# downloaded chank 725
# downloaded chank 726
# downloaded chank 727
# downloaded chank 728
# downloaded chank 729
# downloaded chank 730
# downloaded chank 731
# downloaded chank 732
# downloaded chank 733
# downloaded chank 734
# downloaded chank 735
# downloaded chank 736
# downloaded chank 737
# downloaded chank 738
# downloaded chank 739
# downloaded chank 740
# downloaded chank 741
# downloaded chank 742
# downloaded chank 743
# downloaded chank 744
# downloaded chank 745
# downloaded chank 746
# downloaded chank 747
# downloaded chank 748
# downloaded chank 749
# downloaded chank 750
# downloaded chank 751
# downloaded chank 752
# downloaded chank 753
# downloaded chank 754
# downloaded chank 755
# downloaded chank 756
# downloaded chank 757
# downloaded chank 758
# downloaded chank 759
# downloaded chank 760
# downloaded chank 761
# downloaded chank 762
# downloaded chank 763
# downloaded chank 764
# downloaded chank 765
# downloaded chank 766
# downloaded chank 767
# downloaded chank 768
# downloaded chank 769
# downloaded chank 770
# downloaded chank 771
# downloaded chank 772
# downloaded chank 773
# downloaded chank 774
# downloaded chank 775
# downloaded chank 776
# downloaded chank 777
# downloaded chank 778
# downloaded chank 779
# downloaded chank 780
# downloaded chank 781
# downloaded chank 782
# downloaded chank 783
# downloaded chank 784
# downloaded chank 785
# downloaded chank 786
# downloaded chank 787
# downloaded chank 788
# downloaded chank 789
# downloaded chank 790
# downloaded chank 791
# downloaded chank 792
# downloaded chank 793
# downloaded chank 794
# downloaded chank 795
# downloaded chank 796
# downloaded chank 797
# downloaded chank 798
# downloaded chank 799
# downloaded chank 800
# downloaded chank 801
# downloaded chank 802
# downloaded chank 803
# downloaded chank 804
# downloaded chank 805
# downloaded chank 806
# downloaded chank 807
# downloaded chank 808
# downloaded chank 809
# downloaded chank 810
# downloaded chank 811
# downloaded chank 812
# downloaded chank 813
# downloaded chank 814
# downloaded chank 815
# downloaded chank 816
# downloaded chank 817
# downloaded chank 818
# downloaded chank 819
# downloaded chank 820
# downloaded chank 821
# downloaded chank 822
# downloaded chank 823
# downloaded chank 824
# downloaded chank 825
# downloaded chank 826
# downloaded chank 827
# downloaded chank 828
# downloaded chank 829
# downloaded chank 830
# downloaded chank 831
# downloaded chank 832
# downloaded chank 833
# downloaded chank 834
# downloaded chank 835
# downloaded chank 836
# downloaded chank 837
# downloaded chank 838
# downloaded chank 839
# downloaded chank 840
# downloaded chank 841
# downloaded chank 842
# downloaded chank 843
# downloaded chank 844
# downloaded chank 845
# downloaded chank 846
# downloaded chank 847
# downloaded chank 848
# downloaded chank 849
# downloaded chank 850
# downloaded chank 851
# downloaded chank 852
# downloaded chank 853
# downloaded chank 854
# downloaded chank 855
# downloaded chank 856
# downloaded chank 857
# downloaded chank 858
# downloaded chank 859
# downloaded chank 860
# downloaded chank 861
# downloaded chank 862
# downloaded chank 863
# downloaded chank 864
# downloaded chank 865
# downloaded chank 866
# downloaded chank 867
# downloaded chank 868
# downloaded chank 869
# downloaded chank 870
# downloaded chank 871
# downloaded chank 872
# downloaded chank 873
# downloaded chank 874
# downloaded chank 875
# downloaded chank 876
# downloaded chank 877
# downloaded chank 878
# downloaded chank 879
# downloaded chank 880
# downloaded chank 881
# downloaded chank 882
# downloaded chank 883
# downloaded chank 884
# downloaded chank 885
# downloaded chank 886
# downloaded chank 887
# downloaded chank 888
# downloaded chank 889
# downloaded chank 890
# downloaded chank 891
# downloaded chank 892
# downloaded chank 893
# downloaded chank 894
# downloaded chank 895
# downloaded chank 896
# downloaded chank 897
# downloaded chank 898
# downloaded chank 899
# downloaded chank 900
# downloaded chank 901
# downloaded chank 902
# downloaded chank 903
# downloaded chank 904
# downloaded chank 905
# downloaded chank 906
# downloaded chank 907
# downloaded chank 908
# downloaded chank 909
# downloaded chank 910
# downloaded chank 911
# downloaded chank 912
# downloaded chank 913
# downloaded chank 914
# downloaded chank 915
# downloaded chank 916
# downloaded chank 917
# downloaded chank 918
# downloaded chank 919
# downloaded chank 920
# downloaded chank 921
# downloaded chank 922
# downloaded chank 923
# downloaded chank 924
# downloaded chank 925
# downloaded chank 926
# downloaded chank 927
# downloaded chank 928
# downloaded chank 929
# downloaded chank 930
# downloaded chank 931
# downloaded chank 932
# downloaded chank 933
# downloaded chank 934
# downloaded chank 935
# downloaded chank 936
# downloaded chank 937
# downloaded chank 938
# downloaded chank 939
# downloaded chank 940
# downloaded chank 941
# downloaded chank 942
# downloaded chank 943
# downloaded chank 944
# downloaded chank 945
# downloaded chank 946
# downloaded chank 947
# downloaded chank 948
# downloaded chank 949
# downloaded chank 950
# downloaded chank 951
# downloaded chank 952
# downloaded chank 953
# downloaded chank 954
# downloaded chank 955
# downloaded chank 956
# downloaded chank 957
# downloaded chank 958
# downloaded chank 959
# downloaded chank 960
# downloaded chank 961
# downloaded chank 962
# downloaded chank 963
# downloaded chank 964
# downloaded chank 965
# downloaded chank 966
# downloaded chank 967
# downloaded chank 968
# downloaded chank 969
# downloaded chank 970
# downloaded chank 971
# downloaded chank 972
# downloaded chank 973
# downloaded chank 974
# downloaded chank 975
# downloaded chank 976
# downloaded chank 977
# downloaded chank 978
# downloaded chank 979
# downloaded chank 980
# downloaded chank 981
# downloaded chank 982
# downloaded chank 983
# downloaded chank 984
# downloaded chank 985
# downloaded chank 986
# downloaded chank 987
# downloaded chank 988
# downloaded chank 989
# downloaded chank 990
# downloaded chank 991
# downloaded chank 992
# downloaded chank 993
# downloaded chank 994
# downloaded chank 995
# downloaded chank 996
# downloaded chank 997
# downloaded chank 998
# downloaded chank 999
# downloaded chank 1000
# downloaded chank 1001
# downloaded chank 1002
# downloaded chank 1003
# downloaded chank 1004
# downloaded chank 1005
# downloaded chank 1006
# downloaded chank 1007
# downloaded chank 1008
# downloaded chank 1009
# downloaded chank 1010
# downloaded chank 1011
# downloaded chank 1012
# downloaded chank 1013
# downloaded chank 1014
# downloaded chank 1015
# downloaded chank 1016
# downloaded chank 1017
# downloaded chank 1018
# downloaded chank 1019
# downloaded chank 1020
# downloaded chank 1021
# downloaded chank 1022
# downloaded chank 1023
# downloaded chank 1024
# downloaded chank 1025
# downloaded chank 1026
# downloaded chank 1027
# downloaded chank 1028
# downloaded chank 1029
# downloaded chank 1030
# downloaded chank 1031
# downloaded chank 1032
# downloaded chank 1033
# downloaded chank 1034
# downloaded chank 1035
# downloaded chank 1036
# downloaded chank 1037
# downloaded chank 1038
# downloaded chank 1039
# downloaded chank 1040
# downloaded chank 1041
# downloaded chank 1042
# downloaded chank 1043
# downloaded chank 1044
# downloaded chank 1045
# downloaded chank 1046
# downloaded chank 1047
# downloaded chank 1048
# downloaded chank 1049
# downloaded chank 1050
# downloaded chank 1051
# downloaded chank 1052
# downloaded chank 1053
# downloaded chank 1054
# downloaded chank 1055
# downloaded chank 1056
# downloaded chank 1057
# downloaded chank 1058
# downloaded chank 1059
# downloaded chank 1060
# downloaded chank 1061
# downloaded chank 1062
# downloaded chank 1063
# downloaded chank 1064
# downloaded chank 1065
# downloaded chank 1066
# downloaded chank 1067
# downloaded chank 1068
# downloaded chank 1069
# downloaded chank 1070
# downloaded chank 1071
# downloaded chank 1072
# downloaded chank 1073
# downloaded chank 1074
# downloaded chank 1075
# downloaded chank 1076
# downloaded chank 1077
# downloaded chank 1078
# downloaded chank 1079
# downloaded chank 1080
# downloaded chank 1081
# downloaded chank 1082
# downloaded chank 1083
# downloaded chank 1084
# downloaded chank 1085
# downloaded chank 1086
# downloaded chank 1087
# downloaded chank 1088
# downloaded chank 1089
# downloaded chank 1090
# downloaded chank 1091
# downloaded chank 1092
# downloaded chank 1093
# downloaded chank 1094
# downloaded chank 1095
# downloaded chank 1096
# downloaded chank 1097
# downloaded chank 1098
# downloaded chank 1099
# downloaded chank 1100
# downloaded chank 1101
# downloaded chank 1102
# downloaded chank 1103
# downloaded chank 1104
# downloaded chank 1105
# downloaded chank 1106
# downloaded chank 1107
# downloaded chank 1108
# downloaded chank 1109
# downloaded chank 1110
# downloaded chank 1111
# downloaded chank 1112
# downloaded chank 1113
# downloaded chank 1114
# downloaded chank 1115
# downloaded chank 1116
# downloaded chank 1117
# downloaded chank 1118
# downloaded chank 1119
# downloaded chank 1120
# downloaded chank 1121
# downloaded chank 1122
# downloaded chank 1123
# downloaded chank 1124
# downloaded chank 1125
# downloaded chank 1126
# downloaded chank 1127
# downloaded chank 1128
# downloaded chank 1129
# downloaded chank 1130
# downloaded chank 1131
# downloaded chank 1132
# downloaded chank 1133
# downloaded chank 1134
# downloaded chank 1135
# downloaded chank 1136
# downloaded chank 1137
# downloaded chank 1138
# downloaded chank 1139
# downloaded chank 1140
# downloaded chank 1141
# downloaded chank 1142
# downloaded chank 1143
# downloaded chank 1144
# downloaded chank 1145
# downloaded chank 1146
# downloaded chank 1147
# downloaded chank 1148
# downloaded chank 1149
# downloaded chank 1150
# downloaded chank 1151
# downloaded chank 1152
# downloaded chank 1153
# downloaded chank 1154
# downloaded chank 1155
# downloaded chank 1156
# downloaded chank 1157
# downloaded chank 1158
# downloaded chank 1159
# downloaded chank 1160
# downloaded chank 1161
# downloaded chank 1162
# downloaded chank 1163
# downloaded chank 1164
# downloaded chank 1165
# downloaded chank 1166
# downloaded chank 1167
# downloaded chank 1168
# downloaded chank 1169
# downloaded chank 1170
# downloaded chank 1171
# downloaded chank 1172
# downloaded chank 1173
# downloaded chank 1174
# downloaded chank 1175
# downloaded chank 1176
# downloaded chank 1177
# downloaded chank 1178
# downloaded chank 1179
# downloaded chank 1180
# downloaded chank 1181
# downloaded chank 1182
# downloaded chank 1183
# downloaded chank 1184
# downloaded chank 1185
# downloaded chank 1186
# downloaded chank 1187
# downloaded chank 1188
# downloaded chank 1189
# downloaded chank 1190
# downloaded chank 1191
# downloaded chank 1192
# downloaded chank 1193
# downloaded chank 1194
# downloaded chank 1195
# downloaded chank 1196
# downloaded chank 1197
# downloaded chank 1198
# downloaded chank 1199
# downloaded chank 1200
# downloaded chank 1201
# downloaded chank 1202
# downloaded chank 1203
# downloaded chank 1204
# downloaded chank 1205
# downloaded chank 1206
# downloaded chank 1207
# downloaded chank 1208
# downloaded chank 1209
# downloaded chank 1210
# downloaded chank 1211
# downloaded chank 1212
# downloaded chank 1213
# downloaded chank 1214
# downloaded chank 1215
# downloaded chank 1216
# downloaded chank 1217
# downloaded chank 1218
# downloaded chank 1219
# downloaded chank 1220
# downloaded chank 1221
# downloaded chank 1222
# downloaded chank 1223
# downloaded chank 1224
# downloaded chank 1225
# downloaded chank 1226
# downloaded chank 1227
# downloaded chank 1228
# downloaded chank 1229
# downloaded chank 1230
# downloaded chank 1231
# downloaded chank 1232
# downloaded chank 1233
# downloaded chank 1234
# downloaded chank 1235
# downloaded chank 1236
# downloaded chank 1237
# downloaded chank 1238
# downloaded chank 1239
# downloaded chank 1240
# downloaded chank 1241
# downloaded chank 1242
# downloaded chank 1243
# downloaded chank 1244
# downloaded chank 1245
# downloaded chank 1246
# downloaded chank 1247
# downloaded chank 1248
# downloaded chank 1249
# downloaded chank 1250
# downloaded chank 1251
# downloaded chank 1252
# downloaded chank 1253
# downloaded chank 1254
# downloaded chank 1255
# downloaded chank 1256
# downloaded chank 1257
# downloaded chank 1258
# downloaded chank 1259
# downloaded chank 1260
# downloaded chank 1261
# downloaded chank 1262
# downloaded chank 1263
# downloaded chank 1264
# downloaded chank 1265
# downloaded chank 1266
# downloaded chank 1267
# downloaded chank 1268
# downloaded chank 1269
# downloaded chank 1270
# downloaded chank 1271
# downloaded chank 1272
# downloaded chank 1273
# downloaded chank 1274
# downloaded chank 1275
# downloaded chank 1276
# downloaded chank 1277
# downloaded chank 1278
# downloaded chank 1279
# downloaded chank 1280
# downloaded chank 1281
# downloaded chank 1282
# downloaded chank 1283
# downloaded chank 1284
# downloaded chank 1285
# downloaded chank 1286
# downloaded chank 1287
# downloaded chank 1288
# downloaded chank 1289
# downloaded chank 1290
# downloaded chank 1291
# downloaded chank 1292
# downloaded chank 1293
# downloaded chank 1294
# downloaded chank 1295
# downloaded chank 1296
# downloaded chank 1297
# downloaded chank 1298
# downloaded chank 1299
# downloaded chank 1300
# downloaded chank 1301
# downloaded chank 1302
# downloaded chank 1303
# downloaded chank 1304
# downloaded chank 1305
# downloaded chank 1306
# downloaded chank 1307
# downloaded chank 1308
# downloaded chank 1309
# downloaded chank 1310
# downloaded chank 1311
# downloaded chank 1312
# downloaded chank 1313
# downloaded chank 1314
# downloaded chank 1315
# downloaded chank 1316
# downloaded chank 1317
# downloaded chank 1318
# downloaded chank 1319
# downloaded chank 1320
# downloaded chank 1321
# downloaded chank 1322
# downloaded chank 1323
# downloaded chank 1324
# downloaded chank 1325
# downloaded chank 1326
# downloaded chank 1327
# downloaded chank 1328
# downloaded chank 1329
# downloaded chank 1330
# downloaded chank 1331
# downloaded chank 1332
# downloaded chank 1333
# downloaded chank 1334
# downloaded chank 1335
# downloaded chank 1336
# downloaded chank 1337
# downloaded chank 1338
# downloaded chank 1339
# downloaded chank 1340
# downloaded chank 1341
# downloaded chank 1342
# downloaded chank 1343
# downloaded chank 1344
# downloaded chank 1345
# downloaded chank 1346
# downloaded chank 1347
# downloaded chank 1348
# downloaded chank 1349
# downloaded chank 1350
# downloaded chank 1351
# downloaded chank 1352
# downloaded chank 1353
# downloaded chank 1354
# downloaded chank 1355
# downloaded chank 1356
# downloaded chank 1357
# downloaded chank 1358
# downloaded chank 1359
# downloaded chank 1360
# downloaded chank 1361
# downloaded chank 1362
# downloaded chank 1363
# downloaded chank 1364
# downloaded chank 1365
# downloaded chank 1366
# downloaded chank 1367
# downloaded chank 1368
# downloaded chank 1369
# downloaded chank 1370
# downloaded chank 1371
# downloaded chank 1372
# downloaded chank 1373
# downloaded chank 1374
# downloaded chank 1375
# downloaded chank 1376
# downloaded chank 1377
# downloaded chank 1378
# downloaded chank 1379
# downloaded chank 1380
# downloaded chank 1381
# downloaded chank 1382
# downloaded chank 1383
# downloaded chank 1384
# downloaded chank 1385
# downloaded chank 1386
# downloaded chank 1387
# downloaded chank 1388
# downloaded chank 1389
# downloaded chank 1390
# downloaded chank 1391
# downloaded chank 1392
# downloaded chank 1393
# downloaded chank 1394
# downloaded chank 1395
# downloaded chank 1396
# downloaded chank 1397
# downloaded chank 1398
# downloaded chank 1399
# downloaded chank 1400
# downloaded chank 1401
# downloaded chank 1402
# downloaded chank 1403
# downloaded chank 1404
# downloaded chank 1405
# downloaded chank 1406
# downloaded chank 1407
# downloaded chank 1408
# downloaded chank 1409
# downloaded chank 1410
# downloaded chank 1411
# downloaded chank 1412
# downloaded chank 1413
# downloaded chank 1414
# downloaded chank 1415
# downloaded chank 1416
# downloaded chank 1417
# downloaded chank 1418
# downloaded chank 1419
# downloaded chank 1420
# downloaded chank 1421
# downloaded chank 1422
# downloaded chank 1423
# downloaded chank 1424
# downloaded chank 1425
# downloaded chank 1426
# downloaded chank 1427
# downloaded chank 1428
# downloaded chank 1429
# downloaded chank 1430
# downloaded chank 1431
# downloaded chank 1432
# downloaded chank 1433
# downloaded chank 1434
# downloaded chank 1435
# downloaded chank 1436
# downloaded chank 1437
# downloaded chank 1438
# downloaded chank 1439
# downloaded chank 1440
# downloaded chank 1441
# downloaded chank 1442
# downloaded chank 1443
# downloaded chank 1444
# downloaded chank 1445
# downloaded chank 1446
# downloaded chank 1447
# downloaded chank 1448
# downloaded chank 1449
# downloaded chank 1450
# downloaded chank 1451
# downloaded chank 1452
# downloaded chank 1453
# downloaded chank 1454
# downloaded chank 1455
# downloaded chank 1456
# downloaded chank 1457
# downloaded chank 1458
# downloaded chank 1459
# downloaded chank 1460
# downloaded chank 1461
# downloaded chank 1462
# downloaded chank 1463
# downloaded chank 1464
# downloaded chank 1465
# downloaded chank 1466
# downloaded chank 1467
# downloaded chank 1468
# downloaded chank 1469
# downloaded chank 1470
# downloaded chank 1471
# downloaded chank 1472
# downloaded chank 1473
# downloaded chank 1474
# downloaded chank 1475
# downloaded chank 1476
# downloaded chank 1477
# downloaded chank 1478
# downloaded chank 1479
# downloaded chank 1480
# downloaded chank 1481
# downloaded chank 1482
# downloaded chank 1483
# downloaded chank 1484
# downloaded chank 1485
# downloaded chank 1486
# downloaded chank 1487
# downloaded chank 1488
# downloaded chank 1489
# downloaded chank 1490
# downloaded chank 1491
# downloaded chank 1492
# downloaded chank 1493
# downloaded chank 1494
# downloaded chank 1495
# downloaded chank 1496
# downloaded chank 1497
# downloaded chank 1498
# downloaded chank 1499
# downloaded chank 1500
# downloaded chank 1501
# downloaded chank 1502
# downloaded chank 1503
# downloaded chank 1504
# downloaded chank 1505
# downloaded chank 1506
# downloaded chank 1507
# downloaded chank 1508
# downloaded chank 1509
# downloaded chank 1510
# downloaded chank 1511
# downloaded chank 1512
# downloaded chank 1513
# downloaded chank 1514
# downloaded chank 1515
# downloaded chank 1516
# downloaded chank 1517
# downloaded chank 1518
# downloaded chank 1519
# downloaded chank 1520
# downloaded chank 1521
# downloaded chank 1522
# downloaded chank 1523
# downloaded chank 1524
# downloaded chank 1525
# downloaded chank 1526
# downloaded chank 1527
# downloaded chank 1528
# downloaded chank 1529
# downloaded chank 1530
# downloaded chank 1531
# downloaded chank 1532
# downloaded chank 1533
# downloaded chank 1534
# downloaded chank 1535
# downloaded chank 1536
# downloaded chank 1537
# downloaded chank 1538
# downloaded chank 1539
# downloaded chank 1540
# downloaded chank 1541
# downloaded chank 1542
# downloaded chank 1543
# downloaded chank 1544
# downloaded chank 1545
# downloaded chank 1546
# downloaded chank 1547
# downloaded chank 1548
# downloaded chank 1549
# downloaded chank 1550
# downloaded chank 1551
# downloaded chank 1552
# downloaded chank 1553
# downloaded chank 1554
# downloaded chank 1555
# downloaded chank 1556
# downloaded chank 1557
# downloaded chank 1558
# downloaded chank 1559
# downloaded chank 1560
# downloaded chank 1561
# downloaded chank 1562
# downloaded chank 1563
# downloaded chank 1564
# downloaded chank 1565
# downloaded chank 1566
# downloaded chank 1567
# downloaded chank 1568
# downloaded chank 1569
# downloaded chank 1570
# downloaded chank 1571
# downloaded chank 1572
# downloaded chank 1573
# downloaded chank 1574
# downloaded chank 1575
# downloaded chank 1576
# downloaded chank 1577
# downloaded chank 1578
# downloaded chank 1579
# downloaded chank 1580
# downloaded chank 1581
# downloaded chank 1582
# downloaded chank 1583
# downloaded chank 1584
# downloaded chank 1585
# downloaded chank 1586
# downloaded chank 1587
# downloaded chank 1588
# downloaded chank 1589
# downloaded chank 1590
# downloaded chank 1591
# downloaded chank 1592
# downloaded chank 1593
# downloaded chank 1594
# downloaded chank 1595
# downloaded chank 1596
# downloaded chank 1597
# downloaded chank 1598
# downloaded chank 1599
# downloaded chank 1600
# downloaded chank 1601
# downloaded chank 1602
# downloaded chank 1603
# downloaded chank 1604
# downloaded chank 1605
# downloaded chank 1606
# downloaded chank 1607
# downloaded chank 1608
# downloaded chank 1609
# downloaded chank 1610
# downloaded chank 1611
# downloaded chank 1612
# downloaded chank 1613
# downloaded chank 1614
# downloaded chank 1615
# downloaded chank 1616
# downloaded chank 1617
# downloaded chank 1618
# downloaded chank 1619
# downloaded chank 1620
# downloaded chank 1621
# downloaded chank 1622
# downloaded chank 1623
# downloaded chank 1624
# downloaded chank 1625
# downloaded chank 1626
# downloaded chank 1627
# downloaded chank 1628
# downloaded chank 1629
# downloaded chank 1630
# downloaded chank 1631
# downloaded chank 1632
# downloaded chank 1633
# downloaded chank 1634
# downloaded chank 1635
# downloaded chank 1636
# downloaded chank 1637
# downloaded chank 1638
# downloaded chank 1639
# downloaded chank 1640
# downloaded chank 1641
# downloaded chank 1642
# downloaded chank 1643
# downloaded chank 1644
# downloaded chank 1645
# downloaded chank 1646
# downloaded chank 1647
# downloaded chank 1648
# downloaded chank 1649
# downloaded chank 1650
# downloaded chank 1651
# downloaded chank 1652
# downloaded chank 1653
# downloaded chank 1654
# downloaded chank 1655
# downloaded chank 1656
# downloaded chank 1657
# downloaded chank 1658
# downloaded chank 1659
# downloaded chank 1660
# downloaded chank 1661
# downloaded chank 1662
# downloaded chank 1663
# downloaded chank 1664
# downloaded chank 1665
# downloaded chank 1666
# downloaded chank 1667
# downloaded chank 1668
# downloaded chank 1669
# downloaded chank 1670
# downloaded chank 1671
# downloaded chank 1672
# downloaded chank 1673
# downloaded chank 1674
# downloaded chank 1675
# downloaded chank 1676
# downloaded chank 1677
# downloaded chank 1678
# downloaded chank 1679
# downloaded chank 1680
# downloaded chank 1681
# downloaded chank 1682
# downloaded chank 1683
# downloaded chank 1684
# downloaded chank 1685
# downloaded chank 1686
# downloaded chank 1687
# downloaded chank 1688
# downloaded chank 1689
# downloaded chank 1690
# downloaded chank 1691
# downloaded chank 1692
# downloaded chank 1693
# downloaded chank 1694
# downloaded chank 1695
# downloaded chank 1696
# downloaded chank 1697
# downloaded chank 1698
# downloaded chank 1699
# downloaded chank 1700
# downloaded chank 1701
# downloaded chank 1702
# downloaded chank 1703
# downloaded chank 1704
# downloaded chank 1705
# downloaded chank 1706
# downloaded chank 1707
# downloaded chank 1708
# downloaded chank 1709
# downloaded chank 1710
# downloaded chank 1711
# downloaded chank 1712
# downloaded chank 1713
# downloaded chank 1714
# downloaded chank 1715
# downloaded chank 1716
# downloaded chank 1717
# downloaded chank 1718
# downloaded chank 1719
# downloaded chank 1720
# downloaded chank 1721
# downloaded chank 1722
# downloaded chank 1723
# downloaded chank 1724
# downloaded chank 1725
# downloaded chank 1726
# downloaded chank 1727
# downloaded chank 1728
# downloaded chank 1729
# downloaded chank 1730
# downloaded chank 1731
# downloaded chank 1732
# downloaded chank 1733
# downloaded chank 1734
# downloaded chank 1735
# downloaded chank 1736
# downloaded chank 1737
# downloaded chank 1738
# downloaded chank 1739
# downloaded chank 1740
# downloaded chank 1741
# downloaded chank 1742
# downloaded chank 1743
# downloaded chank 1744
# downloaded chank 1745
# downloaded chank 1746
# downloaded chank 1747
# downloaded chank 1748
# downloaded chank 1749
# downloaded chank 1750
# downloaded chank 1751
# downloaded chank 1752
# downloaded chank 1753
# downloaded chank 1754
# downloaded chank 1755
# downloaded chank 1756
# downloaded chank 1757
# downloaded chank 1758
# downloaded chank 1759
# downloaded chank 1760
# downloaded chank 1761
# downloaded chank 1762
# downloaded chank 1763
# downloaded chank 1764
# downloaded chank 1765
# downloaded chank 1766
# downloaded chank 1767
# downloaded chank 1768
# downloaded chank 1769
# downloaded chank 1770
# downloaded chank 1771
# downloaded chank 1772
# downloaded chank 1773
# downloaded chank 1774
# downloaded chank 1775
# downloaded chank 1776
# downloaded chank 1777
# downloaded chank 1778
# downloaded chank 1779
# downloaded chank 1780
# downloaded chank 1781
# downloaded chank 1782
# downloaded chank 1783
# downloaded chank 1784
# downloaded chank 1785
# downloaded chank 1786
# downloaded chank 1787
# downloaded chank 1788
# downloaded chank 1789
# downloaded chank 1790
# downloaded chank 1791
# downloaded chank 1792
# downloaded chank 1793
# downloaded chank 1794
# downloaded chank 1795
# downloaded chank 1796
# downloaded chank 1797
# downloaded chank 1798
# downloaded chank 1799
# downloaded chank 1800
# downloaded chank 1801
# downloaded chank 1802
# downloaded chank 1803
# downloaded chank 1804
# downloaded chank 1805
# downloaded chank 1806
# downloaded chank 1807
# downloaded chank 1808
# downloaded chank 1809
# downloaded chank 1810
# downloaded chank 1811
# downloaded chank 1812
# downloaded chank 1813
# downloaded chank 1814
# downloaded chank 1815
# downloaded chank 1816
# downloaded chank 1817
# downloaded chank 1818
# downloaded chank 1819
# downloaded chank 1820
# downloaded chank 1821
# downloaded chank 1822
# downloaded chank 1823
# downloaded chank 1824
# downloaded chank 1825
# downloaded chank 1826
# downloaded chank 1827
# downloaded chank 1828
# downloaded chank 1829
# downloaded chank 1830
# downloaded chank 1831
# downloaded chank 1832
# downloaded chank 1833
# downloaded chank 1834
# downloaded chank 1835
# downloaded chank 1836
# downloaded chank 1837
# downloaded chank 1838
# downloaded chank 1839
# downloaded chank 1840
# downloaded chank 1841
# downloaded chank 1842
# downloaded chank 1843
# downloaded chank 1844
# downloaded chank 1845
# downloaded chank 1846
# downloaded chank 1847
# downloaded chank 1848
# downloaded chank 1849
# downloaded chank 1850
# downloaded chank 1851
# downloaded chank 1852
# downloaded chank 1853
# downloaded chank 1854
# downloaded chank 1855
# downloaded chank 1856
# downloaded chank 1857
# downloaded chank 1858
# downloaded chank 1859
# downloaded chank 1860
# downloaded chank 1861
# downloaded chank 1862
# downloaded chank 1863
# downloaded chank 1864
# downloaded chank 1865
# downloaded chank 1866
# downloaded chank 1867
# downloaded chank 1868
# downloaded chank 1869
# downloaded chank 1870
# downloaded chank 1871
# downloaded chank 1872
# downloaded chank 1873
# downloaded chank 1874
# downloaded chank 1875
# downloaded chank 1876
# downloaded chank 1877
# downloaded chank 1878
# downloaded chank 1879
# downloaded chank 1880
# downloaded chank 1881
# downloaded chank 1882
# downloaded chank 1883
# downloaded chank 1884
# downloaded chank 1885
# downloaded chank 1886
# downloaded chank 1887
# downloaded chank 1888
# downloaded chank 1889
# downloaded chank 1890
# downloaded chank 1891
# downloaded chank 1892
# downloaded chank 1893
# downloaded chank 1894
# downloaded chank 1895
# downloaded chank 1896
# downloaded chank 1897
# downloaded chank 1898
# downloaded chank 1899
# downloaded chank 1900
# downloaded chank 1901
# downloaded chank 1902
# downloaded chank 1903
# downloaded chank 1904
# downloaded chank 1905
# downloaded chank 1906
# downloaded chank 1907
# downloaded chank 1908
# downloaded chank 1909
# downloaded chank 1910
# downloaded chank 1911
# downloaded chank 1912
# downloaded chank 1913
# downloaded chank 1914
# downloaded chank 1915
# downloaded chank 1916
# downloaded chank 1917
# downloaded chank 1918
# downloaded chank 1919
# downloaded chank 1920
# downloaded chank 1921
# downloaded chank 1922
# downloaded chank 1923
# downloaded chank 1924
# downloaded chank 1925
# downloaded chank 1926
# downloaded chank 1927
# downloaded chank 1928
# downloaded chank 1929
# downloaded chank 1930
# downloaded chank 1931
# downloaded chank 1932
# downloaded chank 1933
# downloaded chank 1934
# downloaded chank 1935
# downloaded chank 1936
# downloaded chank 1937
# downloaded chank 1938
# downloaded chank 1939
# downloaded chank 1940
# downloaded chank 1941
# downloaded chank 1942
# downloaded chank 1943
# downloaded chank 1944
# downloaded chank 1945
# downloaded chank 1946
# downloaded chank 1947
# downloaded chank 1948
# downloaded chank 1949
# downloaded chank 1950
# downloaded chank 1951
# downloaded chank 1952
# downloaded chank 1953
# downloaded chank 1954
# downloaded chank 1955
# downloaded chank 1956
# downloaded chank 1957
# downloaded chank 1958
# downloaded chank 1959
# downloaded chank 1960
# downloaded chank 1961
# downloaded chank 1962
# downloaded chank 1963
# downloaded chank 1964
# downloaded chank 1965
# downloaded chank 1966
# downloaded chank 1967
# downloaded chank 1968
# downloaded chank 1969
# downloaded chank 1970
# downloaded chank 1971
# downloaded chank 1972
# downloaded chank 1973
# downloaded chank 1974
# downloaded chank 1975
# downloaded chank 1976
# downloaded chank 1977
# downloaded chank 1978
# downloaded chank 1979
# downloaded chank 1980
# downloaded chank 1981
# downloaded chank 1982
# downloaded chank 1983
# downloaded chank 1984
# downloaded chank 1985
# downloaded chank 1986
# downloaded chank 1987
# downloaded chank 1988
# downloaded chank 1989
# downloaded chank 1990
# downloaded chank 1991
# downloaded chank 1992
# downloaded chank 1993
# downloaded chank 1994
# downloaded chank 1995
# downloaded chank 1996
# downloaded chank 1997
# downloaded chank 1998
# downloaded chank 1999
# downloaded chank 2000
# downloaded chank 2001
# downloaded chank 2002
# downloaded chank 2003
# downloaded chank 2004
# downloaded chank 2005
# downloaded chank 2006
# downloaded chank 2007
# downloaded chank 2008
# downloaded chank 2009
# downloaded chank 2010
# downloaded chank 2011
# downloaded chank 2012
# downloaded chank 2013
# downloaded chank 2014
# downloaded chank 2015
# downloaded chank 2016
# downloaded chank 2017
# downloaded chank 2018
# downloaded chank 2019
# downloaded chank 2020
# downloaded chank 2021
# downloaded chank 2022
# downloaded chank 2023
# downloaded chank 2024
# downloaded chank 2025
# downloaded chank 2026
# downloaded chank 2027
# downloaded chank 2028
# downloaded chank 2029
# downloaded chank 2030
# downloaded chank 2031
# downloaded chank 2032
# downloaded chank 2033
# downloaded chank 2034
# downloaded chank 2035
# downloaded chank 2036
# downloaded chank 2037
# downloaded chank 2038
# downloaded chank 2039
# downloaded chank 2040
# downloaded chank 2041
# downloaded chank 2042
# downloaded chank 2043
# downloaded chank 2044
# downloaded chank 2045
# downloaded chank 2046
# downloaded chank 2047
# downloaded chank 2048
# downloaded chank 2049
# downloaded chank 2050
# downloaded chank 2051
# downloaded chank 2052
# downloaded chank 2053
# downloaded chank 2054
# downloaded chank 2055
# downloaded chank 2056
# downloaded chank 2057
# downloaded chank 2058
# downloaded chank 2059
# downloaded chank 2060
# downloaded chank 2061
# downloaded chank 2062
# downloaded chank 2063
# downloaded chank 2064
# downloaded chank 2065
# downloaded chank 2066
# downloaded chank 2067
# downloaded chank 2068
# downloaded chank 2069
# downloaded chank 2070
# downloaded chank 2071
# downloaded chank 2072
# downloaded chank 2073
# downloaded chank 2074
# downloaded chank 2075
# downloaded chank 2076
# downloaded chank 2077
# downloaded chank 2078
# downloaded chank 2079
# downloaded chank 2080
# downloaded chank 2081
# downloaded chank 2082
# downloaded chank 2083
# downloaded chank 2084
# downloaded chank 2085
# downloaded chank 2086
# downloaded chank 2087
# downloaded chank 2088
# downloaded chank 2089
# downloaded chank 2090
# downloaded chank 2091
# downloaded chank 2092
# downloaded chank 2093
# downloaded chank 2094
# downloaded chank 2095
# downloaded chank 2096
# downloaded chank 2097
# downloaded chank 2098
# downloaded chank 2099
# downloaded chank 2100
# downloaded chank 2101
# downloaded chank 2102
# downloaded chank 2103
# downloaded chank 2104
# downloaded chank 2105
# downloaded chank 2106
# downloaded chank 2107
# downloaded chank 2108
# downloaded chank 2109
# downloaded chank 2110
# downloaded chank 2111
# downloaded chank 2112
# downloaded chank 2113
# downloaded chank 2114
# downloaded chank 2115
# downloaded chank 2116
# downloaded chank 2117
# downloaded chank 2118
# downloaded chank 2119
# downloaded chank 2120
# downloaded chank 2121
# downloaded chank 2122
# downloaded chank 2123
# downloaded chank 2124
# downloaded chank 2125
# downloaded chank 2126
# downloaded chank 2127
# downloaded chank 2128
# downloaded chank 2129
# downloaded chank 2130
# downloaded chank 2131
# downloaded chank 2132
# downloaded chank 2133
# downloaded chank 2134
# downloaded chank 2135
# downloaded chank 2136
# downloaded chank 2137
# downloaded chank 2138
# downloaded chank 2139
# downloaded chank 2140
# downloaded chank 2141
# downloaded chank 2142
# downloaded chank 2143
# downloaded chank 2144
# downloaded chank 2145
# downloaded chank 2146
# downloaded chank 2147
# downloaded chank 2148
# downloaded chank 2149
# downloaded chank 2150
# downloaded chank 2151
# downloaded chank 2152
# downloaded chank 2153
# downloaded chank 2154
# downloaded chank 2155
# downloaded chank 2156
# downloaded chank 2157
# downloaded chank 2158
# downloaded chank 2159
# downloaded chank 2160
# downloaded chank 2161
# downloaded chank 2162
# downloaded chank 2163
# downloaded chank 2164
# downloaded chank 2165
# downloaded chank 2166
# downloaded chank 2167
# downloaded chank 2168
# downloaded chank 2169
# downloaded chank 2170
# downloaded chank 2171
# downloaded chank 2172
# downloaded chank 2173
# downloaded chank 2174
# downloaded chank 2175
# downloaded chank 2176
# downloaded chank 2177
# downloaded chank 2178
# downloaded chank 2179
# downloaded chank 2180
# downloaded chank 2181
# downloaded chank 2182
# downloaded chank 2183
# downloaded chank 2184
# downloaded chank 2185
# downloaded chank 2186
# downloaded chank 2187
# downloaded chank 2188
# downloaded chank 2189
# downloaded chank 2190
# downloaded chank 2191
# downloaded chank 2192
# downloaded chank 2193
# downloaded chank 2194
# downloaded chank 2195
# downloaded chank 2196
# downloaded chank 2197
# downloaded chank 2198
# downloaded chank 2199
# downloaded chank 2200
# downloaded chank 2201
# downloaded chank 2202
# downloaded chank 2203
# downloaded chank 2204
# downloaded chank 2205
# downloaded chank 2206
# downloaded chank 2207
# downloaded chank 2208
# downloaded chank 2209
# downloaded chank 2210
# downloaded chank 2211
# downloaded chank 2212
# downloaded chank 2213
# downloaded chank 2214
# downloaded chank 2215
# downloaded chank 2216
# downloaded chank 2217
# downloaded chank 2218
# downloaded chank 2219
# downloaded chank 2220
# downloaded chank 2221
# downloaded chank 2222
# downloaded chank 2223
# downloaded chank 2224
# downloaded chank 2225
# downloaded chank 2226
# downloaded chank 2227
# downloaded chank 2228
# downloaded chank 2229
# downloaded chank 2230
# downloaded chank 2231
# downloaded chank 2232
# downloaded chank 2233
# downloaded chank 2234
# downloaded chank 2235
# downloaded chank 2236
# downloaded chank 2237
# downloaded chank 2238
# downloaded chank 2239
# downloaded chank 2240
# downloaded chank 2241
# downloaded chank 2242
# downloaded chank 2243
# downloaded chank 2244
# downloaded chank 2245
# downloaded chank 2246
# downloaded chank 2247
# downloaded chank 2248
# downloaded chank 2249
# downloaded chank 2250
# downloaded chank 2251
# downloaded chank 2252
# downloaded chank 2253
# downloaded chank 2254
# downloaded chank 2255
# downloaded chank 2256
# downloaded chank 2257
# downloaded chank 2258
# downloaded chank 2259
# downloaded chank 2260
# downloaded chank 2261
# downloaded chank 2262
# downloaded chank 2263
# downloaded chank 2264
# downloaded chank 2265
# downloaded chank 2266
# downloaded chank 2267
# downloaded chank 2268
# downloaded chank 2269
# downloaded chank 2270
# downloaded chank 2271
# downloaded chank 2272
# downloaded chank 2273
# downloaded chank 2274
# downloaded chank 2275
# downloaded chank 2276
# downloaded chank 2277
# downloaded chank 2278
# downloaded chank 2279
# downloaded chank 2280
# downloaded chank 2281
# downloaded chank 2282
# downloaded chank 2283
# downloaded chank 2284
# downloaded chank 2285
# downloaded chank 2286
# downloaded chank 2287
# downloaded chank 2288
# downloaded chank 2289
# downloaded chank 2290
# downloaded chank 2291
# downloaded chank 2292
# downloaded chank 2293
# downloaded chank 2294
# downloaded chank 2295
# downloaded chank 2296
# downloaded chank 2297
# downloaded chank 2298
# downloaded chank 2299
# downloaded chank 2300
# downloaded chank 2301
# downloaded chank 2302
# downloaded chank 2303
# downloaded chank 2304
# downloaded chank 2305
# downloaded chank 2306
# downloaded chank 2307
# downloaded chank 2308
# downloaded chank 2309
# downloaded chank 2310
# downloaded chank 2311
# downloaded chank 2312
# downloaded chank 2313
# downloaded chank 2314
# downloaded chank 2315
# downloaded chank 2316
# downloaded chank 2317
# downloaded chank 2318
# downloaded chank 2319
# downloaded chank 2320
# downloaded chank 2321
# downloaded chank 2322
# downloaded chank 2323
# downloaded chank 2324
# downloaded chank 2325
# downloaded chank 2326
# downloaded chank 2327
# downloaded chank 2328
# downloaded chank 2329
# downloaded chank 2330
# downloaded chank 2331
# downloaded chank 2332
# downloaded chank 2333
# downloaded chank 2334
# downloaded chank 2335
# downloaded chank 2336
# downloaded chank 2337
# downloaded chank 2338
# downloaded chank 2339
# downloaded chank 2340
# downloaded chank 2341
# downloaded chank 2342
# downloaded chank 2343
# downloaded chank 2344
# downloaded chank 2345
# downloaded chank 2346
# downloaded chank 2347
# downloaded chank 2348
# downloaded chank 2349
# downloaded chank 2350
# downloaded chank 2351
# downloaded chank 2352
# downloaded chank 2353
# downloaded chank 2354
# downloaded chank 2355
# downloaded chank 2356
# downloaded chank 2357
# downloaded chank 2358
# downloaded chank 2359
# downloaded chank 2360
# downloaded chank 2361
# downloaded chank 2362
# downloaded chank 2363
# downloaded chank 2364
# downloaded chank 2365
# downloaded chank 2366
# downloaded chank 2367
# downloaded chank 2368
# downloaded chank 2369
# downloaded chank 2370
# downloaded chank 2371
# downloaded chank 2372
# downloaded chank 2373
# downloaded chank 2374
# downloaded chank 2375
# downloaded chank 2376
# downloaded chank 2377
# downloaded chank 2378
# downloaded chank 2379
# downloaded chank 2380
# downloaded chank 2381
# downloaded chank 2382
# downloaded chank 2383
# downloaded chank 2384
# downloaded chank 2385
# downloaded chank 2386
# downloaded chank 2387
# downloaded chank 2388
# downloaded chank 2389
# downloaded chank 2390
# downloaded chank 2391
# downloaded chank 2392
# downloaded chank 2393
# downloaded chank 2394
# downloaded chank 2395
# downloaded chank 2396
# downloaded chank 2397
# downloaded chank 2398
# downloaded chank 2399
# downloaded chank 2400
# downloaded chank 2401
# downloaded chank 2402
# downloaded chank 2403
# downloaded chank 2404
# downloaded chank 2405
# downloaded chank 2406
# downloaded chank 2407
# downloaded chank 2408
# downloaded chank 2409
# downloaded chank 2410
# downloaded chank 2411
# downloaded chank 2412
# downloaded chank 2413
# downloaded chank 2414
# downloaded chank 2415
# downloaded chank 2416
# downloaded chank 2417
# downloaded chank 2418
# downloaded chank 2419
# downloaded chank 2420
# downloaded chank 2421
# downloaded chank 2422
# downloaded chank 2423
# downloaded chank 2424
# downloaded chank 2425
# downloaded chank 2426
# downloaded chank 2427
# downloaded chank 2428
# downloaded chank 2429
# downloaded chank 2430
# downloaded chank 2431
# downloaded chank 2432
# downloaded chank 2433
# downloaded chank 2434
# downloaded chank 2435
# downloaded chank 2436
# downloaded chank 2437
# downloaded chank 2438
# downloaded chank 2439
# downloaded chank 2440
# downloaded chank 2441
# downloaded chank 2442
# downloaded chank 2443
# downloaded chank 2444
# downloaded chank 2445
# downloaded chank 2446
# downloaded chank 2447
# downloaded chank 2448
# downloaded chank 2449
# downloaded chank 2450
# downloaded chank 2451
# downloaded chank 2452
# downloaded chank 2453
# downloaded chank 2454
# downloaded chank 2455
# downloaded chank 2456
# downloaded chank 2457
# downloaded chank 2458
# downloaded chank 2459
# downloaded chank 2460
# downloaded chank 2461
# downloaded chank 2462
# downloaded chank 2463
# downloaded chank 2464
# downloaded chank 2465
# downloaded chank 2466
# downloaded chank 2467
# downloaded chank 2468
# downloaded chank 2469
# downloaded chank 2470
# downloaded chank 2471
# downloaded chank 2472
# downloaded chank 2473
# downloaded chank 2474
# downloaded chank 2475
# downloaded chank 2476
# downloaded chank 2477
# downloaded chank 2478
# downloaded chank 2479
# downloaded chank 2480
# downloaded chank 2481
# downloaded chank 2482
# downloaded chank 2483
# downloaded chank 2484
# downloaded chank 2485
# downloaded chank 2486
# downloaded chank 2487
# downloaded chank 2488
# downloaded chank 2489
# downloaded chank 2490
# downloaded chank 2491
# downloaded chank 2492
# downloaded chank 2493
# downloaded chank 2494
# downloaded chank 2495
# downloaded chank 2496
# downloaded chank 2497
# downloaded chank 2498
# downloaded chank 2499
# downloaded chank 2500
# downloaded chank 2501
# downloaded chank 2502
# downloaded chank 2503
# downloaded chank 2504
# downloaded chank 2505
# downloaded chank 2506
# downloaded chank 2507
# downloaded chank 2508
# downloaded chank 2509
# downloaded chank 2510
# downloaded chank 2511
# downloaded chank 2512
# downloaded chank 2513
# downloaded chank 2514
# downloaded chank 2515
# downloaded chank 2516
# downloaded chank 2517
# downloaded chank 2518
# downloaded chank 2519
# downloaded chank 2520
# downloaded chank 2521
# downloaded chank 2522
# downloaded chank 2523
# downloaded chank 2524
# downloaded chank 2525
# downloaded chank 2526
# downloaded chank 2527
# downloaded chank 2528
# downloaded chank 2529
# downloaded chank 2530
# downloaded chank 2531
# downloaded chank 2532
# downloaded chank 2533
# downloaded chank 2534
# downloaded chank 2535
# downloaded chank 2536
# downloaded chank 2537
# downloaded chank 2538
# downloaded chank 2539
# downloaded chank 2540
# downloaded chank 2541
# downloaded chank 2542
# downloaded chank 2543
# downloaded chank 2544
# downloaded chank 2545
# downloaded chank 2546
# downloaded chank 2547
# downloaded chank 2548
# downloaded chank 2549
# downloaded chank 2550
# downloaded chank 2551
# downloaded chank 2552
# downloaded chank 2553
# downloaded chank 2554
# downloaded chank 2555
# downloaded chank 2556
# downloaded chank 2557
# downloaded chank 2558
# downloaded chank 2559
# downloaded chank 2560
# downloaded chank 2561
# downloaded chank 2562
# downloaded chank 2563
# downloaded chank 2564
# downloaded chank 2565
# downloaded chank 2566
# downloaded chank 2567
# downloaded chank 2568
# downloaded chank 2569
# downloaded chank 2570
# downloaded chank 2571
# downloaded chank 2572
# downloaded chank 2573
# downloaded chank 2574
# downloaded chank 2575
# downloaded chank 2576
# downloaded chank 2577
# downloaded chank 2578
# downloaded chank 2579
# downloaded chank 2580
# downloaded chank 2581
# downloaded chank 2582
# downloaded chank 2583
# downloaded chank 2584
# downloaded chank 2585
# downloaded chank 2586
# downloaded chank 2587
# downloaded chank 2588
# downloaded chank 2589
# downloaded chank 2590
# downloaded chank 2591
# downloaded chank 2592
# downloaded chank 2593
# downloaded chank 2594
# downloaded chank 2595
# downloaded chank 2596
# downloaded chank 2597
# downloaded chank 2598
# downloaded chank 2599
# downloaded chank 2600
# downloaded chank 2601
# downloaded chank 2602
# downloaded chank 2603
# downloaded chank 2604
# downloaded chank 2605
# downloaded chank 2606
# downloaded chank 2607
# downloaded chank 2608
# downloaded chank 2609
# downloaded chank 2610
# downloaded chank 2611
# downloaded chank 2612
# downloaded chank 2613
# downloaded chank 2614
# downloaded chank 2615
# downloaded chank 2616
# downloaded chank 2617
# downloaded chank 2618
# downloaded chank 2619
# downloaded chank 2620
# downloaded chank 2621
# downloaded chank 2622
# downloaded chank 2623
# downloaded chank 2624
# downloaded chank 2625
# downloaded chank 2626
# downloaded chank 2627
# downloaded chank 2628
# downloaded chank 2629
# downloaded chank 2630
# downloaded chank 2631
# downloaded chank 2632
# downloaded chank 2633
# downloaded chank 2634
# downloaded chank 2635
# downloaded chank 2636
# downloaded chank 2637
# downloaded chank 2638
# downloaded chank 2639
# downloaded chank 2640
# downloaded chank 2641
# downloaded chank 2642
# downloaded chank 2643
# downloaded chank 2644
# downloaded chank 2645
# downloaded chank 2646
# downloaded chank 2647
# downloaded chank 2648
# downloaded chank 2649
# downloaded chank 2650
# downloaded chank 2651
# downloaded chank 2652
# downloaded chank 2653
# downloaded chank 2654
# downloaded chank 2655
# downloaded chank 2656
# downloaded chank 2657
# downloaded chank 2658
# downloaded chank 2659
# downloaded chank 2660
# downloaded chank 2661
# downloaded chank 2662
# downloaded chank 2663
# downloaded chank 2664
# downloaded chank 2665
# downloaded chank 2666
# downloaded chank 2667
# downloaded chank 2668
# downloaded chank 2669
# downloaded chank 2670
# downloaded chank 2671
# downloaded chank 2672
# downloaded chank 2673
# downloaded chank 2674
# downloaded chank 2675
# downloaded chank 2676
# downloaded chank 2677
# downloaded chank 2678
# downloaded chank 2679
# downloaded chank 2680
# downloaded chank 2681
# downloaded chank 2682
# downloaded chank 2683
# downloaded chank 2684
# downloaded chank 2685
# downloaded chank 2686
# downloaded chank 2687
# downloaded chank 2688
# downloaded chank 2689
# downloaded chank 2690
# downloaded chank 2691
# downloaded chank 2692
# downloaded chank 2693
# downloaded chank 2694
# downloaded chank 2695
# downloaded chank 2696
# downloaded chank 2697
# downloaded chank 2698
# downloaded chank 2699
# downloaded chank 2700
# downloaded chank 2701
# downloaded chank 2702
# downloaded chank 2703
# downloaded chank 2704
# downloaded chank 2705
# downloaded chank 2706
# downloaded chank 2707
# downloaded chank 2708
# downloaded chank 2709
# downloaded chank 2710
# downloaded chank 2711
# downloaded chank 2712
# downloaded chank 2713
# downloaded chank 2714
# downloaded chank 2715
# downloaded chank 2716
# downloaded chank 2717
# downloaded chank 2718
# downloaded chank 2719
# the whole file is downloaded
